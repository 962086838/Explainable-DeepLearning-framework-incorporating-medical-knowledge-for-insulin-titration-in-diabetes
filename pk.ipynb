# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pk import *

# %%
pku = PkUtil()
# Out:
# usage: ipykernel_launcher.py [-h] [--seed SEED] [--gpus GPUS]
#                              [--workers WORKERS] [--epochs EPOCHS]
#                              [--batch_size BATCH_SIZE] [--ckpt_name CKPT_NAME]
#                              [--loss_name LOSS_NAME]
#                              [--optimizer_name OPTIMIZER_NAME]
#                              [--lr_scheduler_name LR_SCHEDULER_NAME] [--lr LR]
#                              [--max_feature_days MAX_FEATURE_DAYS]
#                              [--min_feature_days MIN_FEATURE_DAYS]
#                              [--patient_limit PATIENT_LIMIT]
#                              [--sugar_miss_maximum SUGAR_MISS_MAXIMUM]
#                              [--mlp_encode_dilation MLP_ENCODE_DILATION]
#                              [--mlp_output_dim MLP_OUTPUT_DIM]
#                              [--mlp_encode_blocks MLP_ENCODE_BLOCKS]
#                              [--mlp_encode_dropout MLP_ENCODE_DROPOUT]
# ...

# %%
# 如果一个病人，max day = 8,那么target_day最多为 8-1=7
pi = pku.pk_single_patient("614606", target_day=6)
# pi = pku.pk_single_patient("977178", target_day=4)
# Out:
# 检查信息:
#           检查      值          检查       值                     检查       值  \
# 0        葡萄糖    6.1          体重    70.2                 糖化血红蛋白    11.7
# 1      C肽 空腹   0.99      C肽 6分钟    2.73                胰岛素 2分钟   18.88
# 2     C肽 2分钟   2.36      C肽 4分钟    3.17                胰岛素 6分钟   26.59
# 3        皮质醇  171.7        皮质醇1     6.2  估算肾小球滤过率(根据CKD-EPI方程)  93.595
# 4       尿白蛋白    2.4     尿白蛋白/肌肝     5.6                   总胆红素     7.6
# 5      直接胆红素    3.2   门冬氨酸氨基转移酶    23.0                    丙草比   1.261
# 6      游离脂肪酸   0.49  低密度脂蛋白胆固醇1  112.11                  总胆固醇1  176.68
# 7  氨基末端利钠肽前体   53.3         舒张压    70.0               抗胰岛素自身抗体     0.0
# 8   胰岛素样生长因子  113.0    丙氨酸氨基转移酶    29.0                    age    70.0
#
#           检查       值
# 0     胰岛素 空腹     2.8
# 1    胰岛素 4分钟   40.89
# 2         酮体     0.0
# 3         肌酐    64.0
# 4       直/总比   0.421
# 5  低密度脂蛋白胆固醇     2.9
# 6      甘油三酯1  102.66
# 7    抗胰岛细胞抗体     0.0
# 8     gender     1.0
# 精简检查信息（性别 1 为男，0 为女）:
# ...
